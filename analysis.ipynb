# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
count_documents  = db['establishments'].count_documents(query)
print(f"Number of establishments with a hygiene score of 20: {count_documents }\n")

# Display the first document in the results using pprint
first_document = db['establishments'].find_one(query)
print("First Document:")
pprint(first_document)
# Out:
# Number of establishments with a hygiene score of 20: 41
#
# First Document:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64fa6d8816a8c8b3278f924c'),
#  'geocode': {'latitude': Decimal128('50.769705'),
# ...

# %%
# Convert the result to a Pandas DataFrame
hygiene = db['establishments'].find(query)
hygiene_df = pd.DataFrame(list(hygiene))

# Display the number of rows in the DataFrame
num_rows = len(hygiene_df)
print(f"Number of rows in the DataFrame: {num_rows}\n")

# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# Number of rows in the DataFrame: 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  64fa6d8816a8c8b3278fac6a   621707                  0
# 1  64fa6d8816a8c8b3278faf91  1130836                  0
# 2  64fa6d8916a8c8b3278fbadd   293783                  0
# 3  64fa6d8916a8c8b3278fc8de   294474                  0
# 4  64fa6d8916a8c8b3278fc8e0  1315095                  0
# 5  64fa6d8916a8c8b3278fcfe5   294900                  0
# 6  64fa6d8916a8c8b3278ff0f4   293756                  0
# 7  64fa6d8916a8c8b3278ff4bb   878523                  0
# 8  64fa6d8916a8c8b3278ff4d6   293772                  0
# 9  64fa6d8916a8c8b3278ff4d7   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
london_regex = {"$regex": "London", "$options": "i"}  # "i" for case-insensitive matching

    # Define the query criteria to find establishments in London with a RatingValue >= 4
query = {
    "LocalAuthorityName": london_regex,
    "RatingValue": {"$gte": 4}
}

    # Use count_documents to count the number of matching documents
count = db['establishments'].count_documents(query)
print(f"Number of establishments in London with a RatingValue >= 4: {count}\n")

    # Find and display the first document in the results
first_document = db['establishments'].find_one(query)
pprint(first_document)
# Out:
# Number of establishments in London with a RatingValue >= 4: 33
#
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64fa6d8816a8c8b3278fac6a'),
# ...

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
london_regex = {"$regex": "London", "$options": "i"}  # "i" for case-insensitive matching
query = {
    "LocalAuthorityName": london_regex,
    "RatingValue": {"$gte": 4}
}

# Use count_documents to display the number of documents in the result
count = db['establishments'].count_documents(query)
print(f"Number of establishments in London with a RatingValue >= 4: {count}\n")

# Display the first document in the results using pprint
first_document = db['establishments'].find_one(query)
pprint(first_document)
# Out:
# Number of establishments in London with a RatingValue >= 4: 33
#
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64fa6d8816a8c8b3278fac6a'),
# ...

# %%
# Convert the result to a Pandas DataFrame
london = db['establishments'].find(query)
london_df = pd.DataFrame(list(london))

# Display the number of rows in the DataFrame
num_rows = len(london_df)
print(f"Number of rows in the DataFrame: {num_rows}\n")

# Display the first 10 rows of the DataFrame
london_df.head(10)
# Out:
# Number of rows in the DataFrame: 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  64fa6d8816a8c8b3278fac6a   621707                  0
# 1  64fa6d8816a8c8b3278faf91  1130836                  0
# 2  64fa6d8916a8c8b3278fbadd   293783                  0
# 3  64fa6d8916a8c8b3278fc8de   294474                  0
# 4  64fa6d8916a8c8b3278fc8e0  1315095                  0
# 5  64fa6d8916a8c8b3278fcfe5   294900                  0
# 6  64fa6d8916a8c8b3278ff0f4   293756                  0
# 7  64fa6d8916a8c8b3278ff4bb   878523                  0
# 8  64fa6d8916a8c8b3278ff4d6   293772                  0
# 9  64fa6d8916a8c8b3278ff4d7   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score
try:
    degree_search = 0.01
    latitude = float(str(restaurant_document.get("geocode", {}).get("latitude")))
    longitude = float(str(restaurant_document.get("geocode", {}).get("longitude")))

    query = {
        "geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
        "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search},
        "RatingValue": 5,
        "BusinessName": "Penang Flavours"
    }
    sort = [("scores.Hygiene", 1)]

    # Print the results
    results = db['establishments'].find(query).sort(sort).limit(5)
    count = 1
    # Print the results
    print("Top 5 establishments with RatingValue of 5, sorted by lowest hygiene score:")
    for establishment in results:
        print(f"#{count}:")
        pprint(establishment)
        count += 1
except Exception as e:
    print(f"Error: {e}")
# Out:
# Top 5 establishments with RatingValue of 5, sorted by lowest hygiene score:

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = float(str(restaurant_document.get("geocode", {}).get("latitude")))
longitude = float(str(restaurant_document.get("geocode", {}).get("longitude")))

query = {
    "geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
    "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search},
    "RatingValue": 5,
    "BusinessName": "Penang Flavours"
}
sort = [("scores.Hygiene", 1)]

# Print the results
results = db[collection_name].find(query).sort(sort).limit(5)

# Print the results
print("Top 5 establishments with RatingValue of 5, sorted by lowest hygiene score:")
for idx, establishment in enumerate(results, 1):
    print(f"#{idx}:")
    pprint(establishment)

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
